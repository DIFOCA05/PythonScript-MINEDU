# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('Minedu_PF').getOrCreate()
type(spark)

df = spark.read.csv("Analisis Estad/csi_curso.csv", inferSchema=True, header=True, sep = ",")
df.printSchema()
# Out:
# root
#  |-- ID TIPO DOCUMENTO: string (nullable = true)
#  |-- NRO DOCUMENTO: integer (nullable = true)
#  |-- EMAIL: string (nullable = true)
#  |-- GENERO: string (nullable = true)
#  |-- APELLIDO PATERNO: string (nullable = true)
#  |-- APELLIDO MATERNO: string (nullable = true)
#  |-- NOMBRES: string (nullable = true)
#  |-- FECHA NACIMIENTO: integer (nullable = true)
#  |-- TELEFONO FIJO: string (nullable = true)
#  |-- TELEFONO CELULAR: string (nullable = true)
#  |-- REGION: string (nullable = true)
#  |-- DESCRIPCION TIPO ENTIDAD: string (nullable = true)
#  |-- DESCRIPCION ID DRE GRE: string (nullable = true)
#  |-- DESCRIPCION ID UGEL: string (nullable = true)
#  |-- IGED: string (nullable = true)
#  |-- DESCRIPCION NIVEL PUESTO: string (nullable = true)
#  |-- DESCRIPCION PUESTO: string (nullable = true)
#  |-- DESCRIPCION REGIMEN LABORAL: string (nullable = true)
#  |-- COMPROMISO18: integer (nullable = true)
#  |-- % AVANCE CURSO: double (nullable = true)
# ...

# %%
#modifcacion del data frame df

# %%
#creacion del sql
df.createOrReplaceTempView('df_sql')
df1 = spark.sql("SELECT * FROM df_sql")
df1.show(5)
# Out:
# +-----------------+-------------+--------------------+---------+----------------+----------------+-------------+----------------+-------------+----------------+------------------+------------------------+----------------------+-------------------+--------------+------------------------+--------------------+---------------------------+------------+--------------+-----------------------+------------------------+-----------+---------------+------------------------+--------------------+------------+--------------+-------------+-----------------+-----------------+-----------------+------------------+-------------+-----------------+-----------------+-----------------+------------------+-------------+-----------------+-----------------+-----------------+------------------+------------------------+-----------------+-----------------+-----------------+------------------+-------------+
# ...

# %%
#convertir a pandas
import pandas as pd


df2 = df.toPandas()
df2
# Out:
#     ID TIPO DOCUMENTO  NRO DOCUMENTO                          EMAIL  \
# 0                 DNI       47716654   eaguilar@drecajamarca.edu.pe
# 1                 DNI        1217172        supergenito@hotmail.com
# 2                 DNI       43877671  royroyer_henry_29@hotmail.com
# 3                 DNI       46123226         karlk_mark@hotmail.com
# 4                 DNI        8876302          sessyalejos@gmail.com
# ..                ...            ...                            ...
# 334               DNI       15448843           cmyactayo1@gmail.com
# 335               DNI       41366671               eryr30@gmail.com
# 336               DNI        9982775        reneyepez1974@gmail.com
# 337               DNI       41818649             yimirz@hotmail.com
# 338               DNI       18209252   escalafon.ugelviru@gmail.com
#
#         GENERO APELLIDO PATERNO   APELLIDO MATERNO         NOMBRES  \
# 0    MASCULINO          AGUILAR            ALVAREZ   ERICK EDUARDO
# ...
