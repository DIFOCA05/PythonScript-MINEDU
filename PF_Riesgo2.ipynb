# %%
import pandas as pd
import numpy as np


curso = "G2-PROGRAMA DE ESPECIALIZACIÓN EN GESTIÓN DEL RIESGO DE DESASTRES EN EL SECTOR EDUCACIÓN"
file = "C:/Users/difoca05/Downloads/"+curso+".csv"

df = pd.read_csv(file)
df
# Out:
#    ID TIPO DOCUMENTO  NRO DOCUMENTO                             EMAIL  \
# 0                DNI       40186718  miriamalarconcervantes@gmail.com
# 1                DNI       23821906             mi_ki1985@hotmail.com
# 2                DNI        4065667       hugoalvarezllanos@gmail.com
# 3                DNI       71540946            ruddyalvis17@gmail.com
# 4                DNI       10779093       escuelasegura2020@gmail.com
# ..               ...            ...                               ...
# 77               DNI       72703079           paola_81092@hotmail.com
# 78               DNI       29384282                 livevipa@yahoo.es
# 79               DNI       40901388         lauricocha.edit@gmail.com
# 80               DNI       24570579          teoyucraal2016@gmail.com
# 81               DNI       29408712                 nilzupi@gmail.com
#
#        GENERO APELLIDO PATERNO APELLIDO MATERNO         NOMBRES  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\difoca05\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\descriptors\base.py:55, in _convert(expected_type, value)
#      54 try:
# ---> 55     value = expected_type(value)
#      56 except:
#
# TypeError: Fill() takes no arguments
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [1], line 2
#       1 import openpyxl
# ----> 2 wb = openpyxl.load_workbook("asd.xlsx")
#
# File c:\Users\difoca05\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\reader\excel.py:317, in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     290 """Open the given filename and return the workbook
#     291
#     292 :param filename: the path to open or a file-like object
# ...
